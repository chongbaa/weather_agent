# %%
import ipykernel
print(ipykernel.__version__)
# Out:
# 7.1.0

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print("是否成功加载:", load_dotenv())  # 应该打印 True
print("密钥是否存在:", bool(os.getenv("OPENAI_API_KEY")))
print("密钥前8位:", os.getenv("OPENAI_API_KEY")[:8] if os.getenv("OPENAI_API_KEY") else "None")
# Out:
# 是否成功加载: True
# 密钥是否存在: True
# 密钥前8位: sk-proj-

# %%
from openai import OpenAI
from dotenv import load_dotenv

# 加载 .env 文件
load_dotenv()

# 直接创建客户端，它会自动读取 OPENAI_API_KEY
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "用中文自我介绍一下"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 你好！我是一款人工智能助手，旨在回答问题和提供信息。我可以帮助你解决各种问题，包括学习、工作、生活等方面的咨询。如果你有任何需要了解的内容，欢迎随时问我！

# %%
import langchain
import numpy

print(langchain.__version__)
print(numpy.__version__)
from langchain_openai import ChatOpenAI
print("全部成功！")

# %%
import sys 
print(sys.path)
# Out:
# ['C:\\Users\\hhy\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'C:\\Users\\hhy\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', 'C:\\Users\\hhy\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'C:\\Users\\hhy\\AppData\\Local\\Programs\\Python\\Python311', 'c:\\Users\\hhy\\Desktop\\lcProject\\.venv', '', 'c:\\Users\\hhy\\Desktop\\lcProject\\.venv\\Lib\\site-packages']
